# %% [markdown]
# <a href="https://colab.research.google.com/github/uluhansmsk/studious-engine/blob/main/phys101_grade_anaylze.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy import stats

def analyze_grades(grades, specific_grade=None):
    # Convert grades to a numpy array
    grades_array = np.array(grades)

    # Calculate basic statistics
    mean = np.mean(grades_array)
    median = np.median(grades_array)

    # Mode handling: check for empty mode
    mode_result = stats.mode(grades_array, keepdims=True)
    mode = mode_result.mode[0] if mode_result.mode.size > 0 else None  # Get mode if available

    std_dev = np.std(grades_array)
    variance = np.var(grades_array)
    minimum = np.min(grades_array)
    maximum = np.max(grades_array)

    # Calculate quartiles
    q1 = np.percentile(grades_array, 25)
    q2 = np.percentile(grades_array, 50)  # Equivalent to the median
    q3 = np.percentile(grades_array, 75)

    # Print statistical results
    print("Grade Analysis:")
    print(f"Mean: {mean:.2f}")
    print(f"Median: {median}")
    print(f"Mode: {mode}")
    print(f"Standard Deviation: {std_dev:.2f}")
    print(f"Variance: {variance:.2f}")
    print(f"Minimum: {minimum}")
    print(f"Maximum: {maximum}")
    print(f"25th Percentile (Q1): {q1}")
    print(f"50th Percentile (Q2 - Median): {q2}")
    print(f"75th Percentile (Q3): {q3}")

    # Check specific grade status
    if specific_grade is not None:
        percentile_rank = stats.percentileofscore(grades_array, specific_grade)

        print(f"\nStatus of Specific Grade {specific_grade}:")
        if specific_grade < mean:
            print(f"{specific_grade} is below the average grade ({mean:.2f}).")
        elif specific_grade > mean:
            print(f"{specific_grade} is above the average grade ({mean:.2f}).")
        else:
            print(f"{specific_grade} is equal to the average grade ({mean:.2f}).")

        print(f"Percentile Rank of {specific_grade}: {percentile_rank}%")

# Example usage
grades = [1, 48, 2, 84, 3, 10, 4, 19, 5, 35, 6, 99, 7, 65, 8, 62, 9, 83, 10, 69, 11, 44, 12, 57, 13, 60, 14, 72, 15, 32, 16, 42, 17, 61, 18, 72, 19, 11, 20, 58, 21, 40, 22, 51, 23, 32, 24, 32, 25, 87, 26, 56, 27, 12, 28, 93, 29, 77, 30, 75, 31, 72, 32, 12, 33, 24, 34, 73, 35, 44, 36, 82, 37, 25, 38, 68, 39, 76, 40, 43, 41, 41, 42, 0, 43, 14, 44, 45, 45, 89, 46, 33, 47, 14, 48, 34, 49, 76, 50, 14, 51, 85, 52, 50, 53, 26, 54, 35, 55, 57, 56, 35, 57, 88, 58, 42, 59, 87, 60, 0, 61, 2, 62, 21, 63, 10, 64, 63, 65, 78, 66, 17, 67, 38, 68, 57, 69, 44, 70, 34, 71, 75, 72, 55, 73, 62, 74, 19, 75, 3, 76, 67, 77, 44, 78, 10, 79, 14, 80, 48, 81, 10, 82, 29, 83, 46, 84, 56, 85, 79, 86, 78, 87, 65, 88, 16, 89, 0, 90, 81, 91, 85, 92, 53, 93, 41, 94, 23, 95, 96, 52, 97, 39, 98, 59, 99, 43, 100, 69, 16, 9, 63, 36, 18, 32, 37, 44, 47, 0, 14, 84, 36, 0, 34, 17, 22, 0, 54, 0, 44, 70, 48, 56, 55
, 63, 65, 67, 82, 66, 63, 11, 67, 76, 96, 57, 70, 32, 81, 77, 22, 35, 83, 37, 67, 60, 37, 32, 69, 49, 14, 62, 0, 70, 15, 98, 79, 70, 74, 52, 39, 81, 67, 23, 33, 41, 70, 0, 75, 83, 69, 76, 71, 47, 37, 75, 63, 43, 84, 88, 56, 64, 32, 39, 52, 68, 45, 41, 2, 35, 58, 23, 13, 0, 54, 10, 43, 69, 59, 0, 0, 52, 64, 0, 91, 25, 52, 44, 78, 66, 86, 43, 52, 32, 81, 94, 32, 0, 42, 8]
specific_grade = 80
analyze_grades(grades, specific_grade)
# Out:
# Grade Analysis:
# Mean: 45.91
# Median: 46.0
# Mode: 0
# Standard Deviation: 26.66
# Variance: 710.74
# Minimum: 0
# Maximum: 100
# 25th Percentile (Q1): 25.0
# 50th Percentile (Q2 - Median): 46.0
# 75th Percentile (Q3): 67.0
#
# Status of Specific Grade 80:
# 80 is above the average grade (45.91).
# Percentile Rank of 80: 88.56968215158923%

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

def analyze_grades(grades, specific_grade=None):
    # Convert grades to a numpy array
    grades_array = np.array(grades)

    # Calculate basic statistics
    mean = np.mean(grades_array)
    median = np.median(grades_array)

    # Mode handling: check for empty mode
    mode_result = stats.mode(grades_array, keepdims=True)
    mode = mode_result.mode[0] if mode_result.mode.size > 0 else None  # Get mode if available

    std_dev = np.std(grades_array)
    variance = np.var(grades_array)
    minimum = np.min(grades_array)
    maximum = np.max(grades_array)

    # Calculate quartiles
    q1 = np.percentile(grades_array, 25)
    q2 = np.percentile(grades_array, 50)  # Equivalent to the median
    q3 = np.percentile(grades_array, 75)

    # Print statistical results
    print("Grade Analysis:")
    print(f"Mean: {mean:.2f}")
    print(f"Median: {median}")
    print(f"Mode: {mode}")
    print(f"Standard Deviation: {std_dev:.2f}")
    print(f"Variance: {variance:.2f}")
    print(f"Minimum: {minimum}")
    print(f"Maximum: {maximum}")
    print(f"25th Percentile (Q1): {q1}")
    print(f"50th Percentile (Q2 - Median): {q2}")
    print(f"75th Percentile (Q3): {q3}")

    # Check specific grade status
    if specific_grade is not None:
        percentile_rank = stats.percentileofscore(grades_array, specific_grade)

        # Count above, below, and equal
        above_count = np.sum(grades_array > specific_grade)
        below_count = np.sum(grades_array < specific_grade)
        equal_count = np.sum(grades_array == specific_grade)

        print(f"\nStatus of Specific Grade {specific_grade}:")
        print(f"Above average grade ({mean:.2f})." if specific_grade > mean else f"Below average grade ({mean:.2f}).")
        print(f"Percentile Rank of {specific_grade}: {percentile_rank}%")
        print(f"Number of grades above {specific_grade}: {above_count}")
        print(f"Number of grades below {specific_grade}: {below_count}")
        print(f"Number of grades equal to {specific_grade}: {equal_count}")

        # Visualize distribution with a histogram
        plt.figure(figsize=(10, 6))
        plt.hist(grades_array, bins=20, color='lightblue', edgecolor='black', alpha=0.7)
        plt.axvline(mean, color='red', linestyle='--', label=f'Mean: {mean:.2f}')
        plt.axvline(median, color='green', linestyle='--', label=f'Median: {median}')
# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

def analyze_grades(grades, specific_grade=None):
    # Convert grades to a numpy array
    grades_array = np.array(grades)

    # Calculate basic statistics for the full dataset
    mean = np.mean(grades_array)
    median = np.median(grades_array)

    # Mode handling: check for empty mode
    mode_result = stats.mode(grades_array, keepdims=True)
    mode = mode_result.mode[0] if mode_result.mode.size > 0 else None  # Get mode if available

    std_dev = np.std(grades_array)
    variance = np.var(grades_array)
    minimum = np.min(grades_array)
    maximum = np.max(grades_array)

    # Calculate quartiles
    q1 = np.percentile(grades_array, 25)
    q2 = np.percentile(grades_array, 50)  # Equivalent to the median
    q3 = np.percentile(grades_array, 75)

    # Print statistical results
    print("Grade Analysis - Full Dataset:")
    print(f"Mean: {mean:.2f}")
    print(f"Median: {median}")
    print(f"Mode: {mode}")
    print(f"Standard Deviation: {std_dev:.2f}")
    print(f"Variance: {variance:.2f}")
    print(f"Minimum: {minimum}")
    print(f"Maximum: {maximum}")
    print(f"25th Percentile (Q1): {q1}")
    print(f"50th Percentile (Q2 - Median): {q2}")
    print(f"75th Percentile (Q3): {q3}")

    # Check specific grade status
    if specific_grade is not None:
        percentile_rank = stats.percentileofscore(grades_array, specific_grade)

        # Count above, below, and equal
        above_count = np.sum(grades_array > specific_grade)
        below_count = np.sum(grades_array < specific_grade)
        equal_count = np.sum(grades_array == specific_grade)

        print(f"\nStatus of Specific Grade {specific_grade}:")
        print(f"Above average grade ({mean:.2f})." if specific_grade > mean else f"Below average grade ({mean:.2f}).")
        print(f"Percentile Rank of {specific_grade}: {percentile_rank}%")
        print(f"Number of grades above {specific_grade}: {above_count}")
        print(f"Number of grades below {specific_grade}: {below_count}")
        print(f"Number of grades equal to {specific_grade}: {equal_count}")

        # Filter grades that are equal to or above the specific grade
        filtered_grades = grades_array[grades_array >= specific_grade]

        # Calculate statistics for the filtered dataset
        filtered_mean = np.mean(filtered_grades)
        filtered_median = np.median(filtered_grades)
        filtered_mode_result = stats.mode(filtered_grades, keepdims=True)
        filtered_mode = filtered_mode_result.mode[0] if filtered_mode_result.mode.size > 0 else None
        filtered_std_dev = np.std(filtered_grades)
        filtered_variance = np.var(filtered_grades)

        print("\nGrade Analysis - Grades Equal to or Above Specific Grade:")
        print(f"Mean: {filtered_mean:.2f}")
        print(f"Median: {filtered_median}")
        print(f"Mode: {filtered_mode}")
        print(f"Standard Deviation: {filtered_std_dev:.2f}")
        print(f"Variance: {filtered_variance:.2f}")
        print(f"Minimum: {np.min(filtered_grades)}")
        print(f"Maximum: {np.max(filtered_grades)}")

        # Plot histogram for the full dataset
        plt.figure(figsize=(10, 6))
        plt.hist(grades_array, bins=20, color='lightblue', edgecolor='black', alpha=0.7)
        plt.axvline(mean, color='red', linestyle='--', label=f'Mean: {mean:.2f}')
        plt.axvline(median, color='green', linestyle='--', label=f'Median: {median}')
        plt.axvline(specific_grade, color='purple', linestyle='-', label=f'Specific Grade: {specific_grade}')
        plt.title('Grade Distribution - Full Dataset')
        plt.xlabel('Grade')
        plt.ylabel('Frequency')
        plt.legend()
        plt.show()

        # Plot histogram for the filtered dataset
        plt.figure(figsize=(10, 6))
        plt.hist(filtered_grades, bins=20, color='salmon', edgecolor='black', alpha=0.7)
        plt.axvline(filtered_mean, color='red', linestyle='--', label=f'Filtered Mean: {filtered_mean:.2f}')
, 57, 89, 15, 10, 45, 54, 91, 57, 83, 33, 61, 0, 17, 15, 44, 46, 21, 35, 15, 30, 67, 0, 62, 42, 38, 54, 56, 84, 75, 0, 86, 43, 39, 92, 25, 91, 82, 76, 33, 92, 57, 17, 28, 31, 0, 18, 0, 37, 38, 54, 78, 22, 47, 26, 35, 78, 0, 27, 56, 84, 88, 60, 25, 52, 27, 71, 23, 35, 74, 51, 61, 55, 38, 64, 30, 0, 53, 28, 42, 63, 62, 38, 0, 73, 21, 8, 0, 0, 32, 11, 33, 86, 25, 36, 22, 20, 63, 35, 47, 35, 17, 68, 18, 17, 34, 71, 50, 38, 71, 20, 82, 22, 59, 60, 4, 28, 47, 45, 72, 41, 93, 31, 46, 32, 20, 28, 47, 46, 60, 49, 55, 60, 6, 15, 41, 29, 25, 38, 69, 4, 39, 32, 2, 24, 51, 33, 50, 0, 60, 22, 0, 58, 13, 64, 33, 89, 53, 88, 0, 0, 12, 32, 59, 43, 82, 73, 20, 24, 33, 91, 62, 74, 57, 85, 59, 45, 24, 53, 66, 38, 50, 29, 36, 84, 30, 61, 87, 65, 81, 51, 69, 93, 0, 50, 61, 16, 55, 80, 33, 50, 59, 55, 77, 79, 71, 97, 72, 45, 33, 0, 79, 30, 79, 44, 47, 69, 16, 6, 87, 66, 41, 0, 49, 45, 69, 81, 50, 61, 53, 37, 64, 83, 57, 0, 5, 0, 48, 91, 49, 45, 19, 79, 60, 50, 77, 26, 64, 30, 96, 20, 53, 74, 18, 62, 33, 23, 28, 49, 35, 21, 80, 53, 39, 49, 0, 0, 0, 0, 10, 69, 69, 25, 73, 25, 0, 44, 73, 51, 32, 0, 83, 15, 63, 65, 67, 82, 66, 63, 11, 67, 76, 96, 57, 70, 32, 81, 77, 22, 35, 83, 37, 67, 60, 37, 32, 69, 49, 14, 62, 0, 70, 15, 98, 79, 70, 74, 52, 39, 81, 67, 23, 33, 41, 70, 0, 75, 83, 69, 76, 71, 47, 37, 75, 63, 43, 84, 88, 56, 64, 32, 39, 52, 68, 45, 41, 2, 35, 58, 23, 13, 0, 54, 10, 43, 69, 59, 0, 0, 52, 64, 0, 91, 25, 52, 44, 78, 66, 86, 43, 52, 32, 81, 94, 32, 0, 42, 8]
specific_grade = 80
analyze_grades(grades, specific_grade)
# Out:
# Grade Analysis - Full Dataset:
# Mean: 45.91
# Median: 46.0
# Mode: 0
# Standard Deviation: 26.66
# Variance: 710.74
# Minimum: 0
# Maximum: 100
# 25th Percentile (Q1): 25.0
# 50th Percentile (Q2 - Median): 46.0
# 75th Percentile (Q3): 67.0
#
# Status of Specific Grade 80:
# Above average grade (45.91).
# Percentile Rank of 80: 88.56968215158923%
# Number of grades above 80: 92
# Number of grades below 80: 722
# Number of grades equal to 80: 4
#
# Grade Analysis - Grades Equal to or Above Specific Grade:
# Mean: 87.67
# Median: 87.0
# Mode: 81
# Standard Deviation: 5.36
# Variance: 28.74
# Minimum: 80
# Maximum: 100
